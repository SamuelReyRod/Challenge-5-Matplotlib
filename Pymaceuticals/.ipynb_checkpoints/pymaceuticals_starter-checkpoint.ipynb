# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
complete_data = pd.merge(study_results,mouse_metadata, on='Mouse ID',how='outer')
# Display the data table for preview
complete_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
complete_data['Mouse ID'].nunique()
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# 12 are not duplicated: b447, d133, f932, h428, l872, n482, o848, t573, u153, v199, x226, x336

#duplicates = complete_data[complete_data.duplicated(subset=['Mouse ID'], keep=False)]
#duplicates

duplicates = complete_data.loc[complete_data.duplicated(subset=['Mouse ID', 'Timepoint']),'Mouse ID'].unique()
duplicates
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
g989_mice = complete_data.duplicated(subset=['Mouse ID', 'Timepoint'])
duplicate_rows = complete_data[g989_mice]
#duplicate_mouse_id = duplicate_rows['Mouse ID'].unique()
duplicate_rows
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 861     g989          0           45.000000                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 869     g989         20           54.657650                 1     Propriva
#
#         Sex  Age_months  Weight (g)
# 861  Female          21          26
# 863  Female          21          26
# 865  Female          21          26
# 867  Female          21          26
# 869  Female          21          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

duplicated_mouse_ids = complete_data.loc[complete_data.duplicated(subset=['Mouse ID', 'Timepoint']), 'Mouse ID'].unique()
rows_to_drop = complete_data['Mouse ID'].isin(duplicated_mouse_ids)
clean_df = complete_data.drop(complete_data[rows_to_drop].index)
clean_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_df['Mouse ID'].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

sum_mean_statistics = complete_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
sum_median_statistics = complete_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
sum_variance_statistics = complete_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
sum_stdev_statistics = complete_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sum_sem_statistics = complete_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

sum_statistics = pd.DataFrame({'Mean Tumor Volume': sum_mean_statistics,'Median Tumor Volume': sum_median_statistics,
                               'Tumor Volume Variance': sum_variance_statistics,'Tumor Volume Std. Dev.': sum_stdev_statistics,
                               'Tumor Volume Std. Err.': sum_sem_statistics})

sum_statistics
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line.

summary_statistics = complete_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std','sem'])
summary_statistics = summary_statistics.rename(columns={'mean': 'Mean Tumor Volume',
                                                       'median':'Median Tumor Volume',
                                                       'var':'Tumor Volume Variance',
                                                       'std':'Tumor Volume Std. Dev.',
                                                       'sem':'Tumor Volume Std. Err.'})
summary_statistics
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
mice_data = complete_data.groupby('Drug Regimen')['Mouse ID'].count()
mice_tested = mice_data.sort_values(ascending=False)
mice_tested.plot(kind='bar', figsize=(8,6), edgecolor='black')

plt.title("Number of Mice Tested per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.xticks(rotation=45)
plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

mice_data = complete_data.groupby('Drug Regimen')['Mouse ID'].count()
mice_tested = mice_data.sort_values(ascending=False)

plt.bar(mice_tested.index, mice_tested.values, edgecolor='black')
plt.title("Number of Mice Tested per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.xticks(rotation=45)
plt.figure(figsize=(8,6))
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
male_female_data = complete_data.groupby('Sex')['Mouse ID'].count()
male_female_data.plot(kind='pie', figsize=(8,6), autopct='%1.1f%%', startangle=0)
plt.title("Distribution of Mice by Sex")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

male_female_data = complete_data.groupby('Sex')['Mouse ID'].count()
plt.figure(figsize=(8,6))
plt.pie(male_female_data.values, labels=male_female_data.index, autopct='%1.f%%', startangle=0)
plt.title("Distribution of Mice by Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse

#Filtering the 4 regimens
treatment_regimens = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']
selected_treatment = complete_data.loc[complete_data['Drug Regimen'].isin(treatment_regimens)]
#sorting on timepoint descending...this will yield the last instance of timepoints and then removing all duplicates
max_timepoint = selected_treatment.sort_values(['Timepoint'], ascending=False)
max_timepoint = max_timepoint.drop_duplicates(subset=['Mouse ID'])
last_tumor_volumes = max_timepoint[['Mouse ID', 'Tumor Volume (mm3)']]
last_tumor_volumes_list = last_tumor_volumes.to_records(index=False).tolist()
last_tumor_volumes_df = pd.DataFrame(last_tumor_volumes_list, columns=['Mouse ID', 'Last Tumor Volume'])            
last_tumor_volumes_df

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
new_clean_merge = pd.merge(complete_data,last_tumor_volumes_df,on='Mouse ID')
new_clean_merge.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)  Last Tumor Volume
# 0  Female           9          22          38.982878
# 1  Female           9          22          38.982878
# 2  Female           9          22          38.982878
# 3  Female           9          22          38.982878
# 4  Female           9          22          38.982878

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)

drug_regimens = ['Capomulin', 'Infubinol', 'Ramicane', 'Ceftamin']
last_tumor_vol_data = []

for drug in drug_regimens:
    drug_data = new_clean_merge.loc[new_clean_merge['Drug Regimen'] == drug, :]
    last_tumor_vol_and_id = drug_data.groupby('Mouse ID').agg({'Timepoint': 'max', 'Last Tumor Volume': 'last'}).reset_index()
    last_tumor_vol_data.extend(list(zip(last_tumor_vol_and_id['Last Tumor Volume'], last_tumor_vol_and_id['Mouse ID'])))

#print(last_tumor_vol_data)

final_tumor_data_df = pd.DataFrame(last_tumor_vol_data, columns=['Last Tumor Volume', 'Mouse ID'])
print(final_tumor_data_df)

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = final_tumor_data_df['Last Tumor Volume'].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Tumor Vol is: {lowerq}")
print(f"The upper quartile of Tumor Vol is: {upperq}")
print(f"The interquartile range of Tumor Vol is: {iqr}")
print(f"The the median of Tumor Vol is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")




    
    # Locate the rows which contain mice on each drug and get the tumor volumes
drug_regimens2 = ['Capomulin', 'Infubinol', 'Ramicane', 'Ceftamin']
last_tumor_vol_data2 = []

for drug2 in drug_regimens:
    drug_data2 = new_clean_merge.loc[new_clean_merge['Drug Regimen'] == drug2, :]
    last_tumor_vol_and_id2 = drug_data2.groupby('Mouse ID').agg({'Timepoint': 'max', 'Last Tumor Volume': 'last'}).reset_index()
    last_tumor_vol_and_id2 = last_tumor_vol_and_id2[['Mouse ID', 'Last Tumor Volume']]
    last_tumor_vol_and_id2['Drug Regimen'] = drug2
    last_tumor_vol_data2.append(last_tumor_vol_and_id2)

drug_result = pd.concat(last_tumor_vol_data2, ignore_index=True)
print(drug_result)   
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
# Out:
#     Last Tumor Volume Mouse ID
# 0           38.982878     b128
# 1           38.939633     b742
# 2           30.485985     f966
# 3           37.074024     g288
# 4           40.159220     g316
# ..                ...      ...
# 95          45.000000     x226
# 96          64.634949     x581
# 97          61.386660     x822
# 98          68.594745     y769
# 99          64.729837     y865
#
# [100 rows x 2 columns]
# The lower quartile of Tumor Vol is: 37.1877438025
# The upper quartile of Tumor Vol is: 59.930261755
# The interquartile range of Tumor Vol is: 22.742517952499995
# The the median of Tumor Vol is: 45.0
# Values below 3.0739668737500097 could be outliers.
# Values above 94.04403868374999 could be outliers.
#    Mouse ID  Last Tumor Volume Drug Regimen
# 0      b128          38.982878    Capomulin
# 1      b742          38.939633    Capomulin
# 2      f966          30.485985    Capomulin
# 3      g288          37.074024    Capomulin
# ...

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
drug_result.boxplot(column='Last Tumor Volume', by='Drug Regimen')

# Set the title and axis labels
plt.title('Last Tumor Volume by Drug Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('Last Tumor Volume')

# Show the plot
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
